# %%
import pandas as pd
import numpy as np
from scipy.stats import chisquare
import os

# List of CSV files to process
base_path = r'C:\Users\willi\CAN_experiments\\'
csv_files = [
    'performance_metrics_correlated_signal.csv',
    'performance_metrics_max_speedometer.csv',
    'performance_metrics_reverse_light_off.csv',
    'performance_metrics_reverse_light_on.csv',
    'performance_metrics_max_engine_coolant.csv'
]

# Function to merge bins with zero or low expected frequencies
def merge_bins(observed_freq, expected_freq, threshold=5):
    """ Merge bins with expected frequencies below the threshold. """
    while any(expected_freq < threshold):
        for i in range(len(expected_freq)):
            if expected_freq[i] < threshold:
                if i == 0:
                    expected_freq[i + 1] += expected_freq[i]
                    observed_freq[i + 1] += observed_freq[i]
                elif i == len(expected_freq) - 1:
                    expected_freq[i - 1] += expected_freq[i]
                    observed_freq[i - 1] += observed_freq[i]
                else:
                    if expected_freq[i - 1] < expected_freq[i + 1]:
                        expected_freq[i - 1] += expected_freq[i]
                        observed_freq[i - 1] += observed_freq[i]
                    else:
                        expected_freq[i + 1] += expected_freq[i]
                        observed_freq[i + 1] += observed_freq[i]
                expected_freq = np.delete(expected_freq, i)
                observed_freq = np.delete(observed_freq, i)
                break
    return observed_freq, expected_freq

# Function to perform chi-squared test
def perform_chi_squared_test(df, version1, version2, bins=10, threshold=5):
    print("Function perform_chi_squared_test")
    
    # Extract the AUC-ROC values for both versions
    version1_values = df[df['version'] == version1]['roc_auc']
    version2_values = df[df['version'] == version2]['roc_auc']
    print("\nStep 1: Extract AUC-ROC values")
    print(f"Version 1 values ({version1}):\n", version1_values.head())
    print(f"Version 2 values ({version2}):\n", version2_values.head())
    
    # Discretize the continuous AUC-ROC values into bins
    #the goal here is to convert continuous AUC-ROC values into discrete bins for our comparison.
    observed_freq, bin_edges = np.histogram(version1_values, bins=bins) #so the np.histogram to bin the values.
    expected_freq, _ = np.histogram(version2_values, bins=bin_edges)
    print("\nStep 2: Discretize bins")
    print("Observed frequencies (version 1):", observed_freq)
    print("Bin edges:", bin_edges)
    print("Expected frequencies (version 2):", expected_freq)#to print our obs and exp freqs along with the bin edges
    
    # Adjust expected frequencies to ensure sums are equal
    #to ensurethat the sum of obs and exp freqs are equal.
    if observed_freq.sum() != expected_freq.sum():
        factor = observed_freq.sum() / expected_freq.sum()
        expected_freq = expected_freq * factor
        print("\nAdjusted Expected Frequencies:", expected_freq)
    
    # Print the version1 values and observed freqs
    print("\nVersion 1 Values (scaled):\n", version1_values.to_numpy() * 100, observed_freq)
    print("\nVersion 2 Values (scaled):\n", version2_values.to_numpy() * 100, expected_freq)

    # Merging bins where expected frequencies are too low to meet chi-squared test assumptions.
    observed_freq, expected_freq = merge_bins(observed_freq, expected_freq, threshold)
    print("\nStep 4: Merge bins with low expected frequencies")
    print("Merged observed frequencies:", observed_freq)
    print("Merged expected frequencies:", expected_freq)
    
    # Calculate degrees of freedom
    degrees_of_freedom = len(observed_freq) - 1
    print("Degrees of freedom:", degrees_of_freedom)
    
    # Perform the chi-squared test
    chi2_stat, p_val = chisquare(f_obs=observed_freq, f_exp=expected_freq)
    print("\nStep 5: Perform chi-squared test")
    print("Chi-squared statistic:", chi2_stat)
    print("P-value:", p_val)
    
    return chi2_stat, p_val, degrees_of_freedom

# Dictionary to store results
chi_squared_results = {}

# Perform chi-squared test for each attack type
for file in csv_files:
    file_path = os.path.join(base_path, file)
    df = pd.read_csv(file_path)
    attack_type = file.replace('performance_metrics_', '').replace('.csv', '')

    # Define the versions
    version1 = 'embeddings_only'
    version2 = 'normalized'

    # Perform chi-squared test
    chi2_stat, p_val, degrees_of_freedom = perform_chi_squared_test(df, version1, version2)

    # Store the results
    chi_squared_results[attack_type] = {
        'chi2_stat': chi2_stat,
        'p_val': p_val,
        'degrees_of_freedom': degrees_of_freedom
    }

# Print the results for each attack type
for attack_type, results in chi_squared_results.items():
    print(f"\nChi-squared test results for '{attack_type}' attack type:")
    print(f"Chi-squared statistic: {results['chi2_stat']}")
    print(f"P-value: {results['p_val']}")
    print(f"Degrees of freedom: {results['degrees_of_freedom']}")
# Out:
# Function perform_chi_squared_test
#
# Step 1: Extract AUC-ROC values
# Version 1 values (embeddings_only):
#  0    0.915093
# 2    0.938126
# 4    0.927775
# 6    0.943781
# 8    0.961502
# Name: roc_auc, dtype: float64
# Version 2 values (normalized):
#  1    0.962256
# 3    0.973305
# 5    0.950076
# 7    0.957467
# 9    0.986297
# Name: roc_auc, dtype: float64
#
# Step 2: Discretize bins
# Observed frequencies (version 1): [14 13 10 17 11 13 10 11 10 10]
# Bin edges: [0.89681196 0.90500789 0.91320382 0.92139975 0.92959567 0.9377916
#  0.94598753 0.95418346 0.96237938 0.97057531 0.97877124]
# Expected frequencies (version 2): [ 0  0  2  4  7 14 14 15 18 12]
#
# Adjusted Expected Frequencies: [ 0.          0.          2.76744186  5.53488372  9.68604651 19.37209302
#  19.37209302 20.75581395 24.90697674 16.60465116]
#
# Version 1 Values (scaled):
#  [91.5092893  93.81264857 92.77750454 94.37811665 96.15015498 92.49423259
#  94.81742814 90.44147051 95.8361179  93.67485892 91.68313688 93.41043317
#  92.18250463 96.21087018 92.24254232 94.06722432 90.13537839 91.12433588
#  90.30250529 92.15503042 96.27037059 94.19724331 93.57584452 95.23630381
#  89.85694099 90.52308507 92.08530589 97.76948861 90.83106008 92.40142665
#  90.10127391 92.40696081 92.31692237 97.4717662  96.63533881 92.83067753
#  89.88500242 96.5191314  95.11625575 90.93488999 97.87712373 90.5059425
#  96.816035   92.10249306 90.50445237 91.99413617 90.31724331 94.524996
#  93.81773846 94.29193584 93.37334835 92.86442905 93.60736109 93.26339522
#  96.22641466 95.25590715 97.3981826  94.79209668 90.48600317 96.95793801
#  96.01000334 95.5386472  90.1233296  92.9414177  91.05890077 96.44403043
#  95.44532375 96.94738308 97.6344218  96.05601647 97.86199865 94.73967909
#  89.98670813 89.79846141 92.4961139  96.45693078 96.80797267 97.58700584
#  90.21703231 90.04793874 97.19592571 92.19119803 94.27245838 97.76500235
#  92.97618857 95.16015531 92.97973519 96.00209713 94.02336712 91.63559703
#  91.91357183 91.80457307 94.06126318 95.46721415 97.49211244 95.39232353
#  96.10904945 91.07116331 92.75907861 93.08588507 95.32890719 92.11587066
#  92.17675928 92.60954268 90.84809755 93.21623337 93.48524917 92.17262437
#  94.21443998 90.86794972 94.48663936 89.68119632 90.92341363 93.80800889
#  94.97238941 90.55949673 91.46571328 91.19797829 96.34856765] [14 13 10 17 11 13 10 11 10 10]
#
# Version 2 Values (scaled):
#  [96.22555393 97.33049348 95.0076327  95.74671668 98.62971639 94.10662018
#  98.24617676 93.10920632 97.44515058 96.39989031 93.43806572 94.87628619
#  96.78520558 97.62461531 93.86190513 98.71298827 91.82616513 92.50082563
#  92.25439546 94.23693978 98.79992378 97.72972685 97.06337408 97.12275361
#  93.92361819 94.16939566 96.43149461 98.84460186 95.65490709 97.35777895
#  94.60064335 96.85425277 96.10783597 98.7938232  98.90464616 94.15489269
#  94.705259   98.29336546 96.4185708  94.59869564 98.96537181 93.33802636
#  97.89694288 95.83689906 95.21546469 93.46431994 93.89483187 96.16827619
#  96.79320041 96.13373231 94.97929238 94.38290525 98.37432966 95.69982125
#  97.96145737 97.56232581 98.49415387 96.66320376 92.84006114 98.35357398
#  98.54080254 98.31697481 95.02242729 96.93782013 95.42222174 98.25069533
#  98.21457661 98.68912502 98.76018442 98.67764137 98.96411223 96.33796254
#  93.8201492  94.75656174 94.36521642 98.28947311 98.81850112 98.60080286
#  93.49381619 93.69499312 98.77777244 94.369799   98.8356613  98.97423922
#  96.39132019 96.35285529 95.04763878 97.43674532 96.33550042 94.48777456
#  96.02057051 93.11687248 97.14554136 98.90652473 98.63415782 98.18471463
#  97.20814857 95.99179946 96.44478879 96.09999634 98.22673286 96.4973648
#  95.17890912 94.00254233 95.20100573 95.12219848 96.28469531 95.47306883
#  96.57652145 94.97672063 96.82747593 91.83253137 95.47014651 96.93242398
#  97.20446464 95.40861638 92.48775504 95.83348449 98.47681277] [ 0.          0.          2.76744186  5.53488372  9.68604651 19.37209302
#  19.37209302 20.75581395 24.90697674 16.60465116]
#
# Step 4: Merge bins with low expected frequencies
# Merged observed frequencies: [54 11 13 10 11 10 10]
# Merged expected frequencies: [ 8.30232558  9.68604651 19.37209302 19.37209302 20.75581395 24.90697674
#  16.60465116]
# Degrees of freedom: 6
#
# Step 5: Perform chi-squared test
# Chi-squared statistic: 274.4720821661998
# P-value: 2.395410480393426e-56
# Function perform_chi_squared_test
#
# Step 1: Extract AUC-ROC values
# Version 1 values (embeddings_only):
#  0    0.862911
# 2    0.879565
# 4    0.867672
# 6    0.923573
# 8    0.960556
# Name: roc_auc, dtype: float64
# Version 2 values (normalized):
#  1    0.886588
# 3    0.921315
# 5    0.893653
# 7    0.952662
# 9    0.975220
# Name: roc_auc, dtype: float64
#
# Step 2: Discretize bins
# Observed frequencies (version 1): [ 7 15 13 19 12 10 14 12  9  8]
# Bin edges: [0.85220563 0.86452141 0.8768372  0.88915299 0.90146877 0.91378456
#  0.92610035 0.93841613 0.95073192 0.9630477  0.97536349]
# Expected frequencies (version 2): [ 0  2  7 10 12 13 21 14  5  9]
#
# Adjusted Expected Frequencies: [ 0.          2.55913978  8.95698925 12.79569892 15.35483871 16.6344086
#  26.87096774 17.91397849  6.39784946 11.51612903]
#
# Version 1 Values (scaled):
#  [86.29109201 87.95653025 86.76719666 92.3573443  96.05558888 85.22056285
#  93.0117284  88.91850781 87.13899934 89.69116013 89.86835265 92.71887747
#  90.56154619 88.67642538 87.17235904 91.54775048 89.64028537 90.19628456
#  89.76614741 89.97640328 88.59080576 87.81576251 94.718318   89.27286231
#  86.6063191  91.882452   86.76613122 89.62392261 96.08150698 89.76730523
#  93.0108057  91.55890438 86.91683917 93.21477321 95.7638449  86.36860633
#  94.50319941 93.72149125 95.89471393 86.50260225 88.98563392 93.77174475
#  85.49174541 94.26174334 87.17353483 88.86028782 88.16533735 93.9237498
#  93.19636209 94.15411388 92.85238783 92.59371263 92.72335797 95.78778286
#  90.80364356 90.56995007 88.65030207 85.28278377 87.51515422 97.28897572
#  95.90241787 88.50294451 97.09049348 89.74946393 88.88574774 87.10260506
#  96.32517871 97.37677171 89.25309749 93.88430368 89.3502987  86.51367233
#  90.05712416 92.01392724 86.73568827 95.29874971 91.34629327 88.1073205
#  92.52123566 94.99067346 89.25572021 93.86023619 90.49025396 97.09421687
#  94.71578069 89.60952835 85.43915407 93.31885058 87.65763842 86.72167732
#  96.69670807 97.53634908 88.54462549 88.93726949 87.25263505 90.85759837
#  95.88465369 93.86060109 95.64433332 88.03463768 94.21716272 96.53351775
#  88.68660042 93.72693833 86.14865419 90.3813678  91.74618539 91.57997322
#  93.68996577 90.19273523 93.52020567 89.65794448 90.00911658 93.71771194
#  94.52672397 90.69807471 91.40570728 91.17628431 90.1552257 ] [ 7 15 13 19 12 10 14 12  9  8]
#
# Version 2 Values (scaled):
#  [88.6588286  92.13153525 89.36527845 95.26623422 97.52197141 87.31573529
#  95.34990591 93.24372245 88.46169479 94.05983253 91.84267373 94.28413367
#  93.16172174 90.36871442 89.1306792  92.62044255 94.44385781 93.8053123
#  92.50335729 92.44731002 90.28004306 90.40643145 97.52787116 90.89566539
#  91.54352601 93.68114333 87.95228517 94.06504755 97.08484099 93.03559265
#  97.61817038 92.95057958 89.19988141 94.97306867 98.74620792 89.35140603
#  98.97323885 95.98683282 96.91195051 88.57811517 92.8994959  98.3529321
#  89.36048637 97.77856614 88.55874203 93.01242929 90.91376551 95.01626335
#  96.48097396 97.83612266 96.7445106  96.26633104 95.00911233 97.20245136
#  92.98064059 93.43070827 92.91971054 89.40967612 91.39345322 98.43097006
#  98.28306303 91.85943899 98.48057909 92.99710976 90.6555358  91.01236389
#  98.65672033 98.52650991 92.76421299 98.46569834 90.74817021 88.16689018
#  91.12628277 94.64925356 91.00791786 97.82817867 94.35958247 89.53439087
#  93.55403222 98.6010327  94.14790518 97.97136925 91.87291767 98.55181086
#  96.97271119 94.29030231 87.30364215 98.2968343  90.96682526 90.14182482
#  98.21991404 98.63856331 90.03408643 92.50327303 88.33107705 94.23769683
#  97.59347608 98.77757459 98.22620054 90.13829256 97.60041524 98.7130577
#  91.54854429 94.90721764 90.36931975 92.94591065 93.51678444 93.00217195
#  96.27758792 92.13278948 96.48925034 92.38237766 94.04213996 97.96593908
#  98.21382852 92.89479559 93.45351988 93.56661776 92.45436913] [ 0.          2.55913978  8.95698925 12.79569892 15.35483871 16.6344086
#  26.87096774 17.91397849  6.39784946 11.51612903]
#
# Step 4: Merge bins with low expected frequencies
# Merged observed frequencies: [35 19 12 10 14 12  9  8]
# Merged expected frequencies: [11.51612903 12.79569892 15.35483871 16.6344086  26.87096774 17.91397849
#   6.39784946 11.51612903]
# Degrees of freedom: 7
#
# Step 5: Perform chi-squared test
# Chi-squared statistic: 64.52540092960261
# P-value: 1.873041410387014e-11
# Function perform_chi_squared_test
#
# Step 1: Extract AUC-ROC values
# Version 1 values (embeddings_only):
#  0    0.909829
# 2    0.930301
# 4    0.919612
# 6    0.939228
# 8    0.900045
# Name: roc_auc, dtype: float64
# Version 2 values (normalized):
#  1    0.926288
# 3    0.944909
# 5    0.937685
# 7    0.956719
# 9    0.945391
# Name: roc_auc, dtype: float64
#
# Step 2: Discretize bins
# Observed frequencies (version 1): [18 12  8 14 17 15 11  5 11  8]
# Bin edges: [0.89140854 0.89997903 0.90854951 0.91711999 0.92569048 0.93426096
#  0.94283145 0.95140193 0.95997242 0.9685429  0.97711339]
# Expected frequencies (version 2): [ 0  2  8  4  9 13 12 12 15 19]
#
# Adjusted Expected Frequencies: [ 0.          2.53191489 10.12765957  5.06382979 11.39361702 16.45744681
#  15.19148936 15.19148936 18.9893617  24.05319149]
#
# Version 1 Values (scaled):
#  [90.98290094 93.03009428 91.96124516 93.92280375 90.00450068 91.85766056
#  93.64277821 89.56492476 96.19078527 93.1876757  91.22799772 93.17256456
#  91.57687508 97.45093144 91.09808774 93.84222518 89.14085404 90.53729135
#  89.9548441  92.12184525 93.9149102  94.15959379 96.04075046 90.44779145
#  96.38189001 95.35205774 89.44142634 94.02053703 89.38215275 93.41392643
#  94.30026085 94.60553704 97.11889785 91.69775171 96.41039606 93.03331675
#  94.88149259 96.09517098 95.37298813 95.98807015 94.61577818 96.03351755
#  96.96512445 96.92557645 90.32148219 90.95074813 89.83283923 92.89461614
#  93.91474861 94.47974591 92.85047253 92.16375641 92.64325484 91.96312913
#  97.50704269 89.63721871 94.44649744 93.40346505 91.12466082 93.74710373
#  89.7085542  93.90691022 96.49560603 90.3542643  91.94130041 94.57320379
#  92.23351486 92.71296379 92.05404666 93.29540167 92.35311231 90.38246147
#  90.85212139 89.82296356 93.16617979 96.41760973 89.92026621 94.81078804
#  92.75789573 96.64120571 92.26805017 95.11822731 92.57618483 93.80563763
#  95.81114487 97.47161671 90.30188838 93.69502027 90.2793472  89.4034127
#  95.57878709 97.60429367 94.26574648 89.76431301 89.67217334 91.84829864
#  92.41928716 89.17413454 96.39418864 93.17412186 97.71133881 96.75108742
#  93.45125135 94.53821335 90.15190816 92.42141939 93.05050971 91.63483419
#  93.97936764 90.20601733 94.62724678 89.17270817 89.63877615 93.16843277
#  93.59202132 90.16939719 89.29180024 89.7020716  91.84833854] [18 12  8 14 17 15 11  5 11  8]
#
# Version 2 Values (scaled):
#  [92.62882745 94.49090351 93.76850971 95.67186985 94.53906502 94.935536
#  96.27996481 90.72699171 97.60699839 96.03804679 94.90365372 96.09529933
#  93.97042063 98.97785767 95.08249922 96.95155472 90.53246577 92.63844249
#  92.92455299 96.61205561 95.6872245  97.95099644 98.56400786 92.92451522
#  97.50867036 96.88732714 93.13405893 95.98518474 93.4649375  96.63097368
#  96.86157469 97.12763102 98.16391316 94.20933265 98.20998247 95.58603615
#  96.77883163 98.40816239 96.52084567 98.73205295 97.32705481 97.88247096
#  98.2804657  98.20187554 91.63392917 92.15480027 92.4341479  96.02934045
#  95.14347976 97.34382263 96.78244819 95.30880789 94.3458513  95.97142391
#  98.68710694 93.90691674 97.20121869 95.33069381 92.90276759 96.84330717
#  91.59008271 97.88621004 97.87331433 91.41517976 93.4264995  97.10862389
#  94.71240249 96.50515011 93.99575713 98.12977408 93.79962551 92.53681619
#  94.45128481 90.93894304 96.11082818 98.28329874 91.20606172 98.05064414
#  97.48392079 98.3412005  95.17114181 97.69758977 96.40682374 97.81973777
#  97.15784085 98.61205115 91.52429024 95.02074761 93.08625404 94.02486538
#  96.75016998 98.73673629 96.38470174 91.34019994 94.38077509 94.00473272
#  97.25205264 91.21572317 97.8232368  97.28907747 98.8370889  97.76873075
#  96.8912557  95.69460504 92.99523189 95.40067992 97.05565101 95.39878006
#  98.82589954 94.67069755 98.18034929 92.76741337 93.66322277 97.03361714
#  97.69907799 91.82510946 93.91814551 94.08117192 94.87276532] [ 0.          2.53191489 10.12765957  5.06382979 11.39361702 16.45744681
#  15.19148936 15.19148936 18.9893617  24.05319149]
#
# Step 4: Merge bins with low expected frequencies
# Merged observed frequencies: [38 14 17 15 11  5 11  8]
# Merged expected frequencies: [12.65957447  5.06382979 11.39361702 16.45744681 15.19148936 15.19148936
#  18.9893617  24.05319149]
# Degrees of freedom: 7
#
# Step 5: Perform chi-squared test
# Chi-squared statistic: 91.44985238359853
# P-value: 6.231429284758343e-17
# Function perform_chi_squared_test
#
# Step 1: Extract AUC-ROC values
# Version 1 values (embeddings_only):
#  0    0.882128
# 2    0.926271
# 4    0.890955
# 6    0.925742
# 8    0.905167
# Name: roc_auc, dtype: float64
# Version 2 values (normalized):
#  1    0.910484
# 3    0.960946
# 5    0.912368
# 7    0.967479
# 9    0.935714
# Name: roc_auc, dtype: float64
#
# Step 2: Discretize bins
# Observed frequencies (version 1): [21 14 15 11 19 12  8  6  5  8]
# Bin edges: [0.88212782 0.89125134 0.90037487 0.90949839 0.91862191 0.92774544
#  0.93686896 0.94599248 0.95511601 0.96423953 0.97336305]
# Expected frequencies (version 2): [ 0  2  8 12 11 16 16  8 17  9]
#
# Adjusted Expected Frequencies: [ 0.          2.4040404   9.61616162 14.42424242 13.22222222 19.23232323
#  19.23232323  9.61616162 20.43434343 10.81818182]
#
# Version 1 Values (scaled):
#  [88.21278204 92.62705292 89.09545008 92.57417055 90.51668938 88.41632779
#  92.85340224 89.71793274 88.81295128 89.53155693 90.00380671 92.81104583
#  91.44931539 92.00501785 89.33261067 92.91033619 89.48543679 90.80597048
#  90.01769843 93.51247369 92.76968592 89.70686167 91.62285965 96.63740963
#  92.42822223 92.91401471 92.54402915 91.74373319 88.76922291 90.31625799
#  92.80180697 93.57675892 92.60117507 91.55262252 95.58735381 94.58940307
#  96.88993288 88.46734155 95.04200989 88.77609526 90.88341739 96.63002606
#  95.32906241 94.28885322 89.08885078 90.36469751 88.79095598 93.80938649
#  93.20713159 93.5208141  92.50559862 92.02075926 92.32784999 91.88123206
#  88.67010375 90.6014056  92.62623912 92.09308    92.41756327 88.49097846
#  94.02319289 92.35178455 88.36687039 96.83296623 90.02729423 89.76929053
#  95.14310283 91.41284371 93.82562786 88.26753981 92.17252097 88.44071082
#  90.13615949 89.99991591 97.12403482 90.98835644 95.91550644 92.07452364
#  96.12548227 94.29590261 88.27787695 89.2370589  88.50046932 89.04289485
#  90.23484431 95.42293033 94.9465686  90.45878498 91.79611877 96.10123931
#  88.87655212 93.39671167 89.26851991 97.33630537 92.26624999 96.61322389
#  89.61687108 97.30190082 88.75707886 88.75357639 95.76852622 95.3404152
#  90.4883681  90.47835601 88.63126626 91.0442187  91.29484555 91.6480974
#  93.40267996 90.58657803 94.31842357 89.73649558 90.20987297 93.4393056
#  94.55057871 90.92269286 91.32579559 90.92664468 92.55085271] [21 14 15 11 19 12  8  6  5  8]
#
# Version 2 Values (scaled):
#  [91.04836154 96.09460404 91.23681156 96.74791967 93.57144625 89.53785915
#  97.68942583 92.60761779 91.75285971 92.93183304 92.50298083 93.94940634
#  93.91805299 95.08570903 92.71236279 95.67184153 92.32222448 92.29437615
#  93.10991715 95.74519245 94.7178161  94.06669377 95.12565385 98.7452048
#  95.93154789 94.30505121 93.69242314 92.92263031 91.11519814 91.65791078
#  94.36350771 97.1278375  94.81843869 95.48798245 98.55668531 97.85916486
#  98.80168047 90.12570374 96.70713077 91.32323728 94.01275763 97.9277763
#  98.21016063 95.92068324 91.36145293 93.32720528 90.54202849 96.5319923
#  95.22559533 98.44968154 96.49656602 93.67806981 96.71284751 95.60912058
#  93.27033297 94.58984316 94.05125012 94.15886725 96.35255036 90.44692984
#  97.00842339 94.70738228 89.79545166 98.50515129 92.41382255 93.31555957
#  96.38715125 92.91505052 96.41884116 91.51195092 93.52418323 92.19357833
#  94.2257682  92.93986316 98.41583466 93.1284845  97.48949978 96.90295647
#  98.39932436 96.23758055 90.20212997 90.62841629 90.48133957 91.41738139
#  91.40056066 98.37018072 97.17805967 91.65217376 96.11698271 97.81638719
#  92.95100236 96.30015677 91.57192554 98.38324242 94.62659687 98.06464352
#  90.72741636 98.68649247 90.72551832 92.31218466 97.8148856  98.48977336
#  94.45533775 91.98115983 91.92118878 92.87307162 94.31123218 93.88923979
#  96.11278601 94.58952412 98.38805008 93.4225159  94.39412522 95.56206497
#  95.69882547 93.66444963 92.45264385 95.57858859 95.71583337] [ 0.          2.4040404   9.61616162 14.42424242 13.22222222 19.23232323
#  19.23232323  9.61616162 20.43434343 10.81818182]
#
# Step 4: Merge bins with low expected frequencies
# Merged observed frequencies: [50 11 19 12  8  6  5  8]
# Merged expected frequencies: [12.02020202 14.42424242 13.22222222 19.23232323 19.23232323  9.61616162
#  20.43434343 10.81818182]
# Degrees of freedom: 7
#
# Step 5: Perform chi-squared test
# Chi-squared statistic: 146.3725902125556
# P-value: 2.3441072349287865e-28
# Function perform_chi_squared_test
#
# Step 1: Extract AUC-ROC values
# Version 1 values (embeddings_only):
#  0    0.934304
# 2    0.858427
# 4    0.944914
# 6    0.915788
# 8    0.939734
# Name: roc_auc, dtype: float64
# Version 2 values (normalized):
#  1    0.973314
# 3    0.880490
# 5    0.974912
# 7    0.940491
# 9    0.978304
# Name: roc_auc, dtype: float64
#
# Step 2: Discretize bins
# Observed frequencies (version 1): [12 10  9  6 13 14 16 20  7 12]
# Bin edges: [0.84006422 0.85371524 0.86736626 0.88101728 0.8946683  0.90831933
#  0.92197035 0.93562137 0.94927239 0.96292342 0.97657444]
# Expected frequencies (version 2): [ 0  5  6  7  9 11 12 12 12 22]
#
# Adjusted Expected Frequencies: [ 0.          6.19791667  7.4375      8.67708333 11.15625    13.63541667
#  14.875      14.875      14.875      27.27083333]
#
# Version 1 Values (scaled):
#  [93.430425   85.84265166 94.4913707  91.5788349  93.97339495 92.7927714
#  94.3682353  92.5241154  89.51310109 94.736413   90.4471057  93.7061001
#  91.6873886  91.86784733 93.3825037  92.3875248  92.2664486  94.0757277
#  90.1520769  86.55468215 86.02033561 90.79219024 88.95074023 97.08186771
#  94.64724379 94.4155861  96.57143369 85.16629879 91.68391801 92.1327782
#  97.38085805 88.06834151 87.3548231  85.40087448 84.23485359 96.93028127
#  93.32071356 94.92292082 87.92350123 92.15966923 84.89563388 90.75842263
#  97.59718177 96.19305261 91.1119508  90.1949488  90.5146058  91.882048
#  90.3906288  94.5575375  94.0200857  94.7738636  93.3733483  88.70806873
#  97.37576619 87.22792226 97.20542783 97.09501723 95.11826273 92.77195542
#  96.16222432 88.08047604 95.80984424 92.59716911 84.19046237 88.83423841
#  86.06612178 97.65744371 90.65751975 90.92198208 92.89743011 89.13109668
#  85.90983645 95.43686712 86.64600244 91.11562694 87.12524933 85.36681806
#  95.9940394  97.53356348 97.3655401  96.61086112 94.76851262 88.63835856
#  85.13402776 89.66856443 87.23532618 85.84848464 84.74925498 94.09483901
#  84.1653051  94.72031441 86.04951781 85.11206961 85.25223173 93.35034588
#  87.41792389 89.8534594  91.75588782 95.97123262 94.11499791 87.76496891
#  85.83451375 84.77632733 92.9817146  93.2939259  90.7797617  93.2070582
#  93.5953275  92.2865196  94.2953789  90.9890151  94.6272468  90.0655653
#  91.1387762  94.0064216  91.98782    84.0064216  88.1997465 ] [12 10  9  6 13 14 16 20  7 12]
#
# Version 2 Values (scaled):
#  [97.33144212 88.04895093 97.49116629 94.04908238 97.83036014 97.18480432
#  97.99057134 94.21063411 91.89450781 96.51279692 93.03998995 95.72352603
#  92.78610351 93.73543527 96.73577215 97.19869143 95.33925146 97.37842926
#  93.41376215 90.54933663 87.98365073 94.1378309  90.87754674 98.8613102
#  97.31487578 96.21963118 98.04735363 86.21200862 94.36607588 94.33917274
#  98.49301621 90.56359406 91.55400664 86.54232423 86.80555629 98.42085852
#  97.34782813 97.74142589 92.18559651 96.55582246 87.50067188 92.68939915
#  98.68626942 98.98255393 95.24488855 92.89130475 95.21447345 96.50184138
#  94.14970186 98.135213   97.01955269 98.89665255 94.89850561 92.0769904
#  98.53083427 91.92455733 98.79348873 98.89070954 97.64713159 94.88822722
#  97.16719222 92.33519064 98.32971687 94.13101499 88.51005185 91.03435409
#  88.82717679 98.96839334 93.10627599 92.17481256 95.72350968 92.76780257
#  90.8147391  97.05689334 90.00478133 92.70686164 89.09147749 90.28666736
#  98.34080821 98.56623372 98.62273338 98.49266748 97.46240615 90.52981383
#  86.39644723 91.46694899 88.35113637 88.30666315 86.85861606 95.79222254
#  86.36691983 95.72485136 90.5722303  87.09162752 89.36491811 94.97587928
#  90.80365615 92.78703354 96.57322309 98.74518665 97.00962144 92.19831946
#  90.082268   86.46813275 95.47575866 97.13574894 92.91110911 96.17462713
#  96.3276373  96.40323733 96.93030773 94.49995412 98.58186915 91.29307434
#  95.16823277 98.30855824 94.32010814 88.26194217 92.07425206] [ 0.          6.19791667  7.4375      8.67708333 11.15625    13.63541667
#  14.875      14.875      14.875      27.27083333]
#
# Step 4: Merge bins with low expected frequencies
# Merged observed frequencies: [22  9  6 13 14 16 20  7 12]
# Merged expected frequencies: [ 6.19791667  7.4375      8.67708333 11.15625    13.63541667 14.875
#  14.875      14.875      27.27083333]
# Degrees of freedom: 8
#
# Step 5: Perform chi-squared test
# Chi-squared statistic: 56.32848775873987
# P-value: 2.434384717556686e-09
#
# Chi-squared test results for 'correlated_signal' attack type:
# Chi-squared statistic: 274.4720821661998
# P-value: 2.395410480393426e-56
# Degrees of freedom: 6
#
# Chi-squared test results for 'max_speedometer' attack type:
# Chi-squared statistic: 64.52540092960261
# P-value: 1.873041410387014e-11
# Degrees of freedom: 7
#
# Chi-squared test results for 'reverse_light_off' attack type:
# Chi-squared statistic: 91.44985238359853
# P-value: 6.231429284758343e-17
# Degrees of freedom: 7
#
# Chi-squared test results for 'reverse_light_on' attack type:
# Chi-squared statistic: 146.3725902125556
# P-value: 2.3441072349287865e-28
# Degrees of freedom: 7
#
# Chi-squared test results for 'max_engine_coolant' attack type:
# Chi-squared statistic: 56.32848775873987
# P-value: 2.434384717556686e-09
# Degrees of freedom: 8
